# %% [markdown]
# <a href="https://colab.research.google.com/github/LiaMajaca/drivechain/blob/main/testingRag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -q \
  llama-index \
  llama-index-llms-openrouter \
  llama-index-embeddings-huggingface \
  llama-index-readers-file \
  llama-index-packs-fusion-retriever \
  sentence-transformers \
  nest-asyncio \
  requests

print("✅ Installation complete")
# Out:
# ✅ Installation complete

# %%
import os
from getpass import getpass
import nest_asyncio

nest_asyncio.apply()

from llama_index.core import Settings
from llama_index.llms.openrouter import OpenRouter
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# Ask for your OpenRouter API key (input is hidden like a password)
os.environ["OPENROUTER_API_KEY"] = getpass("Enter API:  ")

# Configure the LLM (Meta Llama via OpenRouter)
llm = OpenRouter(
    api_key=os.environ["OPENROUTER_API_KEY"],
    model="meta-llama/llama-3.3-70b-instruct:free",
    max_tokens=512,
    temperature=0.1,  # Low = more precise, less “creative”
    timeout=60,
    system_prompt=(
        "You are an expert RAG system that answers ONLY using the provided context. "
        "Never hallucinate. Never guess. If the answer is not in the context, say so. "
        "Provide short, clear, factual responses with 2–4 evidence bullets."
    ),
)

# Configure the embedding model
embed_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)

# Register both with LlamaIndex settings
Settings.llm = llm
Settings.embed_model = embed_model

print("✅ AI model and settings are ready to use")
# Out:
# Enter API:  ··········
# ✅ AI model and settings are ready to use

# %%
import os
import re
import requests

def download_pdf_from_drive(drive_url: str, save_path: str):
    """
    Download a PDF from a Google Drive sharing link and save it locally.
    """
    # Try pattern: /d/<FILE_ID>/
    match = re.search(r"/d/([A-Za-z0-9_-]+)", drive_url)
    if match:
        file_id = match.group(1)
    else:
        # Try pattern: ?id=<FILE_ID>
        match = re.search(r"id=([A-Za-z0-9_-]+)", drive_url)
        if match:
            file_id = match.group(1)
        else:
            raise ValueError("❌ Could not extract file ID from the link.")

    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"
    print(f"📥 Downloading PDF (file ID {file_id})...")

    resp = requests.get(download_url)
    resp.raise_for_status()

    with open(save_path, "wb") as f:
        f.write(resp.content)

    print(f"✅ PDF downloaded → {save_path}")

# Ask for the Drive link
drive_link = input("📌 Paste your Google Drive PDF link here: ").strip()

# Make sure the data folder exists
DATA_DIR = "data"
os.makedirs(DATA_DIR, exist_ok=True)

# Local path for the PDF
pdf_path = os.path.join(DATA_DIR, "source.pdf")

# Download the PDF
download_pdf_from_drive(drive_link, pdf_path)
# Out:
# 📌 Paste your Google Drive PDF link here: https://drive.google.com/file/d/1yE38cmhf0bP32mf_2sX5bcp6UE8XXisM/view?usp=sharing
# 📥 Downloading PDF (file ID 1yE38cmhf0bP32mf_2sX5bcp6UE8XXisM)...
# ✅ PDF downloaded → data/source.pdf

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core.node_parser import SemanticSplitterNodeParser
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# Load the PDF as a document
documents = SimpleDirectoryReader(input_files=[pdf_path]).load_data()
print(f"📄 Loaded {len(documents)} document(s).")

# Embedding model for semantic splitting (can reuse the same model name)
semantic_embed = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

# Create a semantic splitter
parser = SemanticSplitterNodeParser(
    buffer_size=3,
    breakpoint_percentile_threshold=95,
    embed_model=semantic_embed,
)

# Generate semantic nodes (chunks)
nodes = parser.get_nodes_from_documents(documents)

# Add simple metadata to each chunk
for n in nodes:
    n.metadata["source"] = pdf_path
    n.metadata["chunk_type"] = "semantic"

print(f"🔍 Created {len(nodes)} high-quality semantic nodes.")
# Out:
# 📄 Loaded 3 document(s).
# 🔍 Created 5 high-quality semantic nodes.

# %%
from llama_index.core.llama_pack import download_llama_pack

# Download or load the Query Fusion pack
QueryRewritingRetrieverPack = download_llama_pack(
    "QueryRewritingRetrieverPack",
    "./query_rewriting_pack",
)

# Create the advanced retriever using your nodes
query_rewriting_pack = QueryRewritingRetrieverPack(
    nodes,                      # semantic chunks from Step 4
    chunk_size=256,
    vector_similarity_top_k=8,
    fusion_similarity_top_k=8,
    num_queries=6,              # number of query rewrites
)

print("🚀 Advanced Query Fusion RAG Engine Ready!")
# Out:
# 🚀 Advanced Query Fusion RAG Engine Ready!

# %%
def safe_rag_run(question, retries=3):
    """
    Run the RAG pipeline with basic retry logic.
    """
    for attempt in range(retries):
        try:
            resp = query_rewriting_pack.run(question)

            if resp is None or str(resp).strip() == "":
                raise ValueError("Empty LLM response.")

            return resp

        except Exception as e:
            print(f"⚠️ Error: {e}")
            print(f"🔁 Retrying ({attempt+1}/{retries})...")

    return "❌ Could not generate a valid answer after retries."

print("\nRAG Interactive Mode")
print("Ask any question about your PDF.")
print("Type 'end' to exit.\n")

# Interactive Q&A loop
while True:
    user_question = input("🟦 Enter your question: ").strip()

    if user_question.lower() == "end":
        print("\n👋 Session ended.")
        break

    print("\n🔍 Retrieving answer...\n")

    # Run the question through the RAG pipeline
    response = safe_rag_run(user_question)

    print("\n──────────────────────────────────────────────")
    print("❓ QUESTION:")
    print(user_question)
    print("\n🧠 ANSWER:")
    print(response)
    print("──────────────────────────────────────────────\n")
# Out:
# RAG Interactive Mode
# Ask any question about your PDF.
# Type 'end' to exit.
#
# 🟦 Enter your question: What are the main goals in this document?
#
# 🔍 Retrieving answer...
#
# Generated queries:
# What are the primary objectives outlined in the document?
# What key targets are specified in the document's introduction?
# What are the main purposes and aims stated in the document's abstract?
# What goals and outcomes are explicitly mentioned throughout the document?
# What are the central themes and intentions that the document aims to achieve?
#
# ──────────────────────────────────────────────
# ❓ QUESTION:
# What are the main goals in this document?
#
# 🧠 ANSWER:
# The main goals are to:
# * Define the institution’s academic expectations and standards
# * Provide clear guidance on attendance, assessment, and student conduct
# * Outline the structure and objectives of the curriculum
# * Ensure consistency, fairness, and transparency in academic delivery
# * Support student success through clear responsibilities and evaluation criteria
# ──────────────────────────────────────────────
#
# 🟦 Enter your question: What does this policy say about attendance?
#
# 🔍 Retrieving answer...
#
# Generated queries:
# What are the attendance requirements outlined in this policy?
# How does the policy define excessive absenteeism and its consequences?
# What are the procedures for reporting and tracking attendance according to this policy?
# What are the penalties or disciplinary actions for violating the attendance policy?
# How does the policy accommodate exceptions or special circumstances related to attendance, such as sick leave or family emergencies?
#
# ──────────────────────────────────────────────
# ❓ QUESTION:
# What does this policy say about attendance?
#
# 🧠 ANSWER:
# Here are the key points about attendance:
# * Students are expected to attend all scheduled lectures, tutorials, labs, and official academic activities.
# * A minimum attendance rate of 75% is required to remain in good academic standing.
# * Absences must be supported by valid documentation, such as medical certificates or official letters.
# * Repeated or unexplained absences may result in disciplinary action or exclusion from assessment.
# ──────────────────────────────────────────────
#
# 🟦 Enter your question: Summarise the key points in chapter one.
#
# 🔍 Retrieving answer...
#
# Generated queries:
# What are the main points discussed in chapter one of the book?
# What is a brief summary of the first chapter of the novel?
# Can you outline the key takeaways from chapter one of the textbook?
# What are the primary concepts introduced in the first chapter of the study guide?
# How can I get a concise overview of the main ideas presented in chapter one of the article?
#
# ──────────────────────────────────────────────
# ❓ QUESTION:
# Summarise the key points in chapter one.
#
# 🧠 ANSWER:
# The key points in Chapter One include:
# * An overview of the subject area and its real-world relevance
# * Definitions of key terms and foundational principles
# * Introduction to tools, methods, or frameworks used throughout the course
# * Expectations regarding learning outcomes and student engagement
# * Ethical considerations and professional standards
# ──────────────────────────────────────────────
#
# 🟦 Enter your question: List all the responsibilities of students mentioned in this document.
#
# 🔍 Retrieving answer...
#
# Generated queries:
# What are the key responsibilities of students as outlined in the document?
# What duties and obligations are expected from students according to the document?
# List the specific tasks and roles assigned to students as per the document.
# What are the academic and non-academic responsibilities of students mentioned in the document?
# What obligations and commitments are students required to fulfill as stated in the document?
#
# ──────────────────────────────────────────────
# ❓ QUESTION:
# List all the responsibilities of students mentioned in this document.
#
# 🧠 ANSWER:
# Here are the student responsibilities mentioned:
# * Attend classes and participate actively in learning activities
# * Complete assignments, projects, and assessments on time
# * Adhere to academic integrity and avoid plagiarism or misconduct
# * Familiarise themselves with course materials and institutional policies
# ──────────────────────────────────────────────
#
# 🟦 Enter your question: How is assessment described in this curriculum?
#
# 🔍 Retrieving answer...
#
# Generated queries:
# What are the key components of assessment in this curriculum?
# How does this curriculum define the purpose and scope of assessment?
# What methods of assessment are outlined in this curriculum framework?
# How does the curriculum describe the role of feedback in the assessment process?
# What are the criteria and standards used for evaluating student performance in this curriculum?
#
# ──────────────────────────────────────────────
# ❓ QUESTION:
# How is assessment described in this curriculum?
#
# 🧠 ANSWER:
# Assessment is described as:
# * Continuous and varied, including tests, assignments, projects, presentations, and examinations
# * Aligned with learning outcomes, ensuring assessments measure intended competencies
# * Transparent, with clear marking criteria and rubrics provided in advance
# * Formative and summative, allowing for both feedback-driven improvement and final evaluation
# ──────────────────────────────────────────────
